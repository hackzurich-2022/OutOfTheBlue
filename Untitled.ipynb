# %%
from turtle import filling
import matplotlib.pyplot as plt

import keras_ocr

# %%
# keras-ocr will automatically download pretrained
# weights for the detector and recognizer.
pipeline = keras_ocr.pipeline.Pipeline()

# Get a set of three example images
images = [keras_ocr.tools.read("./Floor/Preprocessed/2.jpg")]

prediction_groups = pipeline.recognize(images)

# Plot the predictions
# fig, axs = plt.subplots(nrows=len(images), figsize=(20, 20))
# Out:
# Looking for C:\Users\sebas\.keras-ocr\craft_mlt_25k.h5
# WARNING:tensorflow:Entity <bound method UpsampleLike.call of <keras_ocr.detection.UpsampleLike object at 0x000001C4FD4B4188>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method UpsampleLike.call of <keras_ocr.detection.UpsampleLike object at 0x000001C4FD4B4188>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method UpsampleLike.call of <keras_ocr.detection.UpsampleLike object at 0x000001C4FD4B4188>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method UpsampleLike.call of <keras_ocr.detection.UpsampleLike object at 0x000001C4FD4B4188>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method UpsampleLike.call of <keras_ocr.detection.UpsampleLike object at 0x000001C4FD673988>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method UpsampleLike.call of <keras_ocr.detection.UpsampleLike object at 0x000001C4FD673988>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method UpsampleLike.call of <keras_ocr.detection.UpsampleLike object at 0x000001C4FD673988>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method UpsampleLike.call of <keras_ocr.detection.UpsampleLike object at 0x000001C4FD673988>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method UpsampleLike.call of <keras_ocr.detection.UpsampleLike object at 0x000001C4FD801D08>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method UpsampleLike.call of <keras_ocr.detection.UpsampleLike object at 0x000001C4FD801D08>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method UpsampleLike.call of <keras_ocr.detection.UpsampleLike object at 0x000001C4FD801D08>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method UpsampleLike.call of <keras_ocr.detection.UpsampleLike object at 0x000001C4FD801D08>>: AttributeError: module 'gast' has no attribute 'Num'
# Looking for C:\Users\sebas\.keras-ocr\crnn_kurapan.h5
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10964\4188317547.py in <module>
#       4
#       5 # Get a set of three example images
# ----> 6 images = [keras_ocr.tools.read("./Floor/test/1.jpg")]
#       7
#       8 prediction_groups = pipeline.recognize(images)
#
# c:\Users\sebas\anaconda3\envs\blender\lib\site-packages\keras_ocr\tools.py in read(filepath_or_buffer)
#      33             return read(urllib.request.urlopen(filepath_or_buffer))
#      34         assert os.path.isfile(filepath_or_buffer), (
# ---> 35             "Could not find image at path: " + filepath_or_buffer
#      36         )
#      37         image = cv2.imread(filepath_or_buffer)
#
# AssertionError: Could not find image at path: ./Floor/test/1.jpg

# %%
predicted_image_1 = prediction_groups[0]
for text, box in predicted_image_1:
    print(text, box)
# Out:
# zipz [[660.   185.  ]
#  [681.25 185.  ]
#  [681.25 192.5 ]
#  [660.   192.5 ]]
# aeo [[488.75 198.75]
#  [505.   198.75]
#  [505.   206.25]
#  [488.75 206.25]]
# aa [[581.25 198.75]
#  [597.5  198.75]
#  [597.5  206.25]
#  [581.25 206.25]]
# 1o [[668.75 198.75]
#  [678.75 198.75]
#  [678.75 206.25]
#  [668.75 206.25]]
# s [[752.5  198.75]
#  [758.75 198.75]
#  [758.75 206.25]
#  [752.5  206.25]]
# 90 [[758.75 198.75]
#  [770.   198.75]
#  [770.   206.25]
#  [758.75 206.25]]
# 4t [[846.25 198.75]
#  [862.5  198.75]
#  [862.5  206.25]
#  [846.25 206.25]]
# basement [[ 972.5  255. ]
#  [1105.   255. ]
#  [1105.   280. ]
#  [ 972.5  280. ]]
# plan [[1108.75  255.  ]
#  [1166.25  255.  ]
#  [1166.25  280.  ]
#  [1108.75  280.  ]]
# sc [[972.5  281.25]
#  [998.75 281.25]
#  [998.75 302.5 ]
#  [972.5  302.5 ]]
# 1209 [[1002.5   281.25]
#  [1047.5   281.25]
#  [1047.5   298.75]
#  [1002.5   298.75]]
# iparking [[ 980.4325   303.37064]
#  [1069.9431   309.20825]
#  [1068.4537   332.0459 ]
#  [ 978.9431   326.20825]]
# e [[522.5  316.25]
#  [552.5  316.25]
#  [552.5  448.75]
#  [522.5  448.75]]
# 25 [[977.5  331.25]
#  [997.5  331.25]
#  [997.5  350.  ]
#  [977.5  350.  ]]
# vertical [[1000.    331.25]
#  [1072.5   331.25]
#  [1072.5   351.25]
#  [1000.    351.25]]
# access [[1075.    333.75]
#  [1138.75  333.75]
#  [1138.75  351.25]
#  [1075.    351.25]]
# warehouse [[1000.0678   354.1371 ]
#  [1108.9965   355.73895]
#  [1108.6906   376.54324]
#  [ 999.7619   374.94138]]
# ss [[978.75 356.25]
#  [997.5  356.25]
#  [997.5  375.  ]
#  [978.75 375.  ]]
# 110 [[633.75 377.5 ]
#  [663.75 377.5 ]
#  [663.75 390.  ]
#  [633.75 390.  ]]
# s [[410.   396.25]
#  [418.75 396.25]
#  [418.75 413.75]
#  [410.   413.75]]
# s [[396.25 442.5 ]
#  [405.   442.5 ]
#  [405.   465.  ]
#  [396.25 465.  ]]
# r [[410.   458.75]
#  [418.75 458.75]
#  [418.75 476.25]
#  [410.   476.25]]
# s [[411.25 515.  ]
#  [417.5  515.  ]
#  [417.5  531.25]
#  [411.25 531.25]]

# %%
keras_ocr.tools.drawAnnotations(image=images[0], predictions=predicted_image_1)
# Out:
# <AxesSubplot:>
